# %% [markdown]
# Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5 using Python. Interpret the results.

# %%
import scipy.stats as stat
import numpy as np 
confidence_interval=0.95
mean=50
std_dev=5
n=100

std_error=std_dev/(n**0.5)
conf_int=stat.t.interval(confidence_interval,loc=mean,scale=std_error,df=n-1)
conf_int
# Out:
# (49.00789152424566, 50.99210847575434)

# %% [markdown]
#  Q3.Use Python to calculate the chi-square statistic and p-value for a contingency table with the following
# data:

# %%
import scipy.stats as stat
import numpy as np
data=[[20,10,15],[15,25,20]]
stat,p,dof,expected=stat.chi2_contingency(data)
sign_value=0.05
print("p value is " + str(p))
# Out:
# p value is 0.05411376622282158

# %% [markdown]
# Q5.Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation
# of 12 using Python. Interpret the results.

# %%
import scipy.stats as stat
import numpy as np 
confidence_interval=0.90
mean=75
std_dev=12
n=100

std_error=std_dev/(n**0.10)
conf_int=stat.t.interval(confidence_interval,loc=mean,scale=std_error,df=n-1)
conf_int
# Out:
# (62.42836806496943, 87.57163193503057)

# %% [markdown]
#  Q6.Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the area corresponding to a chi-square statistic of 15.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stat
x=np.linspace(0,30,1000)
y=stat.chi2.pdf(x,df=10)
plt.plot(x,y,'b-',lw=2)
xshade=np.linspace(15,30,100)
yshade=stat.chi2.pdf(xshade,df=10)
plt.fill_between(xshade,yshade,0,color='red',alpha=0.5)
plt.xlabel("Chi-square value")
plt.ylabel('Probability density')
plt.title('Chi-Square Distribution with 10 degrees of freedom')
plt.show()

# %% [markdown]
# Q4.A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the population who smoke.

# %%
import scipy.stats as stat
import numpy as np

sample_size=500
smokers=60
p=smokers/sample_size

std_error=np.sqrt((p*(1-p)))/sample_size
conf_int=stat.norm.interval(0.95,loc=p,scale=std_error)
conf_int
# Out:
# (0.11872617418543145, 0.12127382581456854)
