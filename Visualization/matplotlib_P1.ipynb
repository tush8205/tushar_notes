# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.10083842,  0.20064886,  0.2984138 ,  0.39313661,
#         0.48385164,  0.56963411,  0.64960951,  0.72296256,  0.78894546,
#         0.84688556,  0.8961922 ,  0.93636273,  0.96698762,  0.98775469,
#         0.99845223,  0.99897117,  0.98930624,  0.96955595,  0.93992165,
#         0.90070545,  0.85230712,  0.79522006,  0.73002623,  0.65739025,
#         0.57805259,  0.49282204,  0.40256749,  0.30820902,  0.21070855,
#         0.11106004,  0.01027934, -0.09060615, -0.19056796, -0.28858706,
#        -0.38366419, -0.47483011, -0.56115544, -0.64176014, -0.7158225 ,
#        -0.7825875 , -0.84137452, -0.89158426, -0.93270486, -0.96431712,
#        -0.98609877, -0.99782778, -0.99938456, -0.99075324, -0.97202182,
#        -0.94338126, -0.90512352, -0.85763861, -0.80141062, -0.73701276,
#        -0.66510151, -0.58640998, -0.50174037, -0.41195583, -0.31797166,
#        -0.22074597, -0.12126992, -0.0205576 ,  0.0803643 ,  0.18046693,
#         0.27872982,  0.37415123,  0.46575841,  0.55261747,  0.63384295,
#         0.7086068 ,  0.77614685,  0.83577457,  0.8868821 ,  0.92894843,
#         0.96154471,  0.98433866,  0.99709789,  0.99969234,  0.99209556,
#         0.97438499,  0.94674118,  0.90944594,  0.86287948,  0.8075165 ,
#         0.74392141,  0.6727425 ,  0.59470541,  0.51060568,  0.42130064,
#         0.32770071,  0.23076008,  0.13146699,  0.03083368, -0.07011396,
#        -0.17034683, -0.26884313, -0.36459873, -0.45663749, -0.54402111])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("this is my X data ")
plt.ylabel("this is my Y data")
plt.title("Sin Curve")
plt.show()

# %%
x=np.random.rand(50)

# %%
y=np.random.rand(50)

# %%
x
# Out:
# array([0.67715999, 0.13586909, 0.04323996, 0.0895233 , 0.61426202,
#        0.5770325 , 0.37012088, 0.76573973, 0.59005016, 0.28204661,
#        0.78400265, 0.64221724, 0.64692069, 0.45773979, 0.08969355,
#        0.37175906, 0.52611758, 0.17981824, 0.46792967, 0.51653209,
#        0.5056463 , 0.54039079, 0.33626318, 0.71628171, 0.85206412,
#        0.86811533, 0.84757051, 0.54244479, 0.47923193, 0.56983502,
#        0.38334275, 0.32882033, 0.66830958, 0.51978425, 0.7127714 ,
#        0.84213214, 0.05541422, 0.56619019, 0.10335338, 0.20848504,
#        0.89185069, 0.37182359, 0.93343041, 0.07716448, 0.92042554,
#        0.1635257 , 0.53214972, 0.47262981, 0.18253256, 0.33785564])

# %%
y
# Out:
# array([0.52505466, 0.91767585, 0.3375551 , 0.51796508, 0.91507966,
#        0.9547646 , 0.28136349, 0.19627929, 0.44186506, 0.88509563,
#        0.83538135, 0.9272031 , 0.30928502, 0.33846231, 0.13268145,
#        0.94694201, 0.8099293 , 0.45739852, 0.34375904, 0.14075116,
#        0.32390234, 0.60064952, 0.64740844, 0.61427449, 0.70475431,
#        0.90408354, 0.6187904 , 0.1012004 , 0.45474265, 0.76756628,
#        0.67420027, 0.37961596, 0.08067553, 0.46631741, 0.71839232,
#        0.2877681 , 0.22722327, 0.64283831, 0.03799212, 0.80394511,
#        0.4969989 , 0.16163449, 0.62394611, 0.48797185, 0.01953752,
#        0.05994754, 0.47792303, 0.61428629, 0.768611  , 0.44496306])

# %%
plt.scatter(x,y)

# %%
colours=np.random.rand(50)
plt.scatter(x,y,c=colours)

# %%
colours=np.random.rand(50)
sizes=100*np.random.rand(50)
plt.scatter(x,y,c=colours,s=sizes)
plt.xlabel("x axis")
plt.ylabel("Y axis")
plt.title("Random Data")
# Out:
# Text(0.5, 1.0, 'Random Data')

# %%
x=['a','b','c','d','e']#categorial vs numberical

# %%
y= np.random.rand(5)

# %%
plt.bar(x,y)
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
y
# Out:
# array([0.80669362, 0.89169526, 0.93433287, 0.95737735, 0.46606527])

# %%
plt.barh(x,y)
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
plt.figure(figsize=(12,6))
plt.plot(x,y,'--v')
plt.xlabel("this is my X data ")
plt.ylabel("this is my Y data")
plt.title("Sin Curve")
plt.grid()
plt.show()

# %%
x=np.random.rand(50)
y=np.random.rand(50)
colours=np.random.rand(50)
sizes=100*np.random.rand(50)
plt.scatter(x,y,c='#06F3E1',s=sizes,marker='o')
plt.xlabel("x axis")
plt.ylabel("Y axis")
plt.title("Random Data")
# Out:
# Text(0.5, 1.0, 'Random Data')

# %%
x=[4,5,6,7,8,9,10]
y=[6,7,4,9,5,12,10]
plt.plot(x,y)
plt.show()

# %%
x=[4,5,6,7,8,9,10]
y=[6,7,4,9,5,12,10]
plt.scatter(x,y)
plt.show()

# %%
data=[1,2,3,5,6,7,8,9,2,3,4,6,7]

# %%
plt.hist(data)
plt.show()

# %%
x=[4,5,6,7,8,9,10]
y=[6,7,4,9,5,12,10]
colour=['red','blue','#06F3E1','#F9F207','#0C07F9','white','#E420C4']
plt.scatter(x,y,c=colour)
plt.show()

# %%
x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)
ax.scatter(x,y,z,c=colours)
fig=plt.figure()
ax=fig.add_subplot(projection='3d')
ax.scatter3D(x,y,z)
plt.show()
