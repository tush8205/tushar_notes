# %% [markdown]
# Q1.Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.
# ANS:
# 1.Line Plot-This plot help us to  to see the ralationship between x-axis and y axis.
# 2.Count Plot:- A counr plot is used to show the counts of Obsrvation in each categorical bin useing bar.
# 3.Bar Plot:- A bar chart is a way of comparing a set of categorical data.
# 4.Histogram: Is a graph that shows the underlying frequnecy Distribution of a set of countinous data.
# 5.Pair Plot: Pair plot craete a gris of axis such that each numeric variable in data will create  a plot between each other.

# %% [markdown]
# Q2. Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x ="timepoint" and y = "signal" for different events and regions.

# %%
import seaborn as sns

# %%
fmri=sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
plot1=sns.lineplot(x=fmri.timepoint,y=fmri.signal,data=fmri,hue="event")
plot1
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
plot2=sns.lineplot(x=fmri.timepoint,y=fmri.signal,data=fmri,hue="region",style='event')
plot2
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# Q3. Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x ='pclass', y = 'age' and y = 'fare'.

# %%
titanic=sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
box1=sns.boxplot(x=titanic.pclass,y=titanic.age)

# %%
box2=sns.boxplot(x=titanic.pclass,y=titanic.fare)

# %% [markdown]
# Q4.: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.

# %%
import seaborn as sns
diamond=sns.load_dataset("diamonds")
diamond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamond=sns.displot(diamond,x='price',hue='cut')
diamond

# %% [markdown]
# Q5.Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
# of the iris dataset.

# %%
import seaborn as sns
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pair_plot=sns.pairplot(iris,hue='species')
pair_plot

# %% [markdown]
# Q6.Use the "flights" dataset from seaborn to plot a heatmap.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
sns.set()
flight=sns.load_dataset('flights')
flight=flight.pivot("month","year","passengers")
ax=sns.heatmap(flight)
plt.show()
# Out:
# C:\Users\tushar.ahire01\AppData\Local\Temp\ipykernel_24280\366412803.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flight=flight.pivot("month","year","passengers")
